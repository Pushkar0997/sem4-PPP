# %%
import numpy as np

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('students.csv')
df.head()
# Out:
#    StudentID   Name Department  Age  Marks
# 0          1  Rahul         IT   20     85
# 1          2  Priya        CSE   21     90
# 2          3   Amit         IT   20     78
# 3          4  Sneha        CSE   22     88
# 4          5  Karan         AI   21     92

# %%
x= df['Department']
y=df['Marks']

# %%
plt.scatter(x,y)

# %%
col= np.random.rand(30)
print(col)
# Out:
# [0.23175647 0.62451932 0.09399858 0.40192182 0.0101542  0.30335548
#  0.46816616 0.25379062 0.45257553 0.82193963 0.71931448 0.34631002
#  0.23241123 0.35770864 0.21929021 0.06762797 0.24606622 0.99597231
#  0.70603557 0.69133987 0.00503395 0.61097814 0.03911858 0.81307837
#  0.24060514 0.70194022 0.8760143  0.08923666 0.3717482  0.35795534]

# %%
plt.hist(y,edgecolor='black')
# Out:
# (array([2., 2., 3., 3., 2., 5., 4., 3., 3., 3.]),
#  array([73. , 75.2, 77.4, 79.6, 81.8, 84. , 86.2, 88.4, 90.6, 92.8, 95. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(y,'auto')
# Out:
# (array([3., 5., 4., 7., 6., 5.]),
#  array([73.        , 76.66666667, 80.33333333, 84.        , 87.66666667,
#         91.33333333, 95.        ]),
#  <BarContainer object of 6 artists>)
